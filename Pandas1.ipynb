# %%
import numpy as np
import pandas as pd
from numpy.random import randn
np.random.seed(101)

# %% [markdown]
# #series

# %%
label=['a','b']
my_list=[10,20]
arr=np.array([10,20])
d={'a':10,'b':20}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# dtype: int64

# %%
pd.Series(arr,label)
# Out:
# a    10
# b    20
# dtype: int32

# %% [markdown]
# #series indexing

# %%
ser1=pd.Series([1,2],index=['A','B'])

# %%
df=pd.DataFrame(randn(5,4),index='A B C D E'.split(),columns='W X Y Z'.split())

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #selection

# %% [markdown]
# ##selection

# %%
df['new']=df['W']+df['Z']
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.210676
# B  0.651118 -0.319318 -0.848077  0.605965  1.257083
# C -2.018168  0.740122  0.528813 -0.589001 -2.607169
# D  0.188695 -0.758872 -0.933237  0.955057  1.143752
# E  0.190794  1.978757  2.605967  0.683509  0.874303

# %%
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %% [markdown]
# #ILOC

# %%
df>0
# Out:
#        W      X      Y      Z    new
# A   True   True   True   True   True
# B   True  False  False   True   True
# C  False   True   True  False  False
# D   True  False  False   True   True
# E   True   True   True   True   True

# %%
sal=pd.read_csv("C:\\Users\\tinti\\Downloads\\DSclass\\Salaries.csv")

# %%
sal.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
sal.head(10)
# Out:
#    Id        EmployeeName                                        JobTitle  \
# 0   1      NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2        GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3      ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4   CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5     PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5   6      DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# 6   7           ALSON LEE              BATTALION CHIEF, (FIRE DEPARTMENT)
# 7   8       DAVID KUSHNER                  DEPUTY DIRECTOR OF INVESTMENTS
# 8   9      MICHAEL MORRIS              BATTALION CHIEF, (FIRE DEPARTMENT)
# 9  10  JOANNE HAYES-WHITE          CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# ...

# %%
sal.tail()
# Out:
#             Id   EmployeeName                    JobTitle  BasePay  \
# 148649  148650  Roy I Tillery                   Custodian      0.0
# 148650  148651   Not provided                Not provided      NaN
# 148651  148652   Not provided                Not provided      NaN
# 148652  148653   Not provided                Not provided      NaN
# 148653  148654      Joe Lopez  Counselor, Log Cabin Ranch      0.0
#
#         OvertimePay  OtherPay  Benefits  TotalPay  TotalPayBenefits  Year  \
# 148649          0.0      0.00       0.0      0.00              0.00  2014
# 148650          NaN       NaN       NaN      0.00              0.00  2014
# 148651          NaN       NaN       NaN      0.00              0.00  2014
# 148652          NaN       NaN       NaN      0.00              0.00  2014
# 148653          0.0   -618.13       0.0   -618.13           -618.13  2014
#
#         Notes         Agency  Status
# 148649    NaN  San Francisco     NaN
# 148650    NaN  San Francisco     NaN
# ...

# %%
sal.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
sal.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
#avg base pay
comp1=sal.groupby('BasePay')
comp1.mean()
# Out:
#                   Id  OvertimePay  OtherPay  Benefits   TotalPay  \
# BasePay
# -166.01      72833.0       249.02      0.00      6.56      83.01
# -121.63      72866.0       182.70      0.00      5.44      61.07
# -109.22      72873.0       163.83      0.00      4.32      54.61
# -106.60      72875.0       159.90      0.00      4.66      53.30
# -101.88      72879.0       153.08      0.00      4.55      51.20
# ...              ...          ...       ...       ...        ...
#  313312.52   72932.0         0.00      0.00  82319.51  313312.52
#  313686.01   72927.0         0.00  23236.00  85431.39  336922.01
#  315572.01   72930.0         0.00      0.00  82849.66  315572.01
#  318835.49  110533.0     10712.95  60563.54  89540.23  390111.98
#  319275.01   72926.0         0.00  20007.06  86533.21  339282.07
#
#             TotalPayBenefits    Year  Notes  Status
# BasePay
# -166.01                89.57  2012.0    NaN     NaN
# -121.63                66.51  2012.0    NaN     NaN
# ...

# %%
#max overtime pay
comp1=sal.groupby('OvertimePay')

# %%
comp1.max()
# Out:
#                  Id        EmployeeName                              JobTitle  \
# OvertimePay
# -0.01         90715   Claudia M Sanchez             Senior Eligibility Worker
#  0.00        148654          Zuri Jones                           ZOO CURATOR
#  0.02         44426   Leonid Vaynshteyn                   Maintenance Planner
#  0.52         99025     Pamela J Walker                        Deputy Sheriff
#  0.77         33722       JANIEN BISHOP  PUBLIC SERVICE AIDE-SPECIAL PROGRAMS
# ...             ...                 ...                                   ...
#  173547.73   110575  Antonio B Santiago                        Deputy Sheriff
#  192424.49    36164   Frederick Binkley             EMT/Paramedic/Firefighter
#  196689.18    72965       Whitney P Yee                        Deputy Sheriff
#  220909.48    36160      Gary Altenberg          Lieutenant, Fire Suppression
#  245131.88        2        GARY JIMENEZ       CAPTAIN III (POLICE DEPARTMENT)
#
# ...

# %%
maxValue = sal.nlargest(1,"TotalPay")
maxValue
# Out:
# Maximum value
# 567595.43

# %%
maxValue = sal.nlargest(1,"TotalPay")
maxValue
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18          0.0  400184.25       NaN  567595.43         567595.43
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN

# %%
Employee1= sal.loc[sal['TotalPay'].idxmax()]
Employee1
# Out:
# Id                                                               1
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       NaN
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Notes                                                          NaN
# Agency                                               San Francisco
# Status                                                         NaN
# Name: 0, dtype: object

# %%
df = sal.groupby(['EmployeeName'])['TotalPay'].max()
df.index
# Out:
# Index(['A BERNARD FATOOH', 'A Bernard  Fatooh', 'A Bernard Fatooh',
#        'A ELIZABETH MARCHASIN', 'A JAMIL NIAZI', 'A K Finizio',
#        'A. JAMES ROBERTSON II', 'A. James  Robertson Ii',
#        'A. James Robertson Ii', 'A.K.  Finizio',
#        ...
#        'Zulaikha Khalil', 'Zulema G Gutierrez', 'Zulema Gutierrez',
#        'Zulma V Merino-Fuentes', 'Zun Jin  Zhang He', 'Zun Jin Zhang He',
#        'Zuna Luu', 'Zuna T Luu', 'Zuri  Jones', 'Zuri Jones'],
#       dtype='object', name='EmployeeName', length=110811)

# %%
pl= sal['JobTitle'].value_counts().head()
pl
# Out:
# Transit Operator                7036
# Special Nurse                   4389
# Registered Nurse                3736
# Public Svc Aide-Public Works    2518
# Police Officer 3                2421
# Name: JobTitle, dtype: int64

# %%
pl= sal.groupby('EmployeeName').value_counts()
pl
# Out:
# Series([], dtype: int64)

# %%
df3= pd.DataFrame({'A':['A0','A1','A2','A3','A4','A5','A6','A7'],'B':['A0','A1','A2','A3','A4','A5','A6','A7'],'C':['A0','A1','A2','A3','A4','A5','A6','A7'],'D':['A0','A1','A2','A3','A4','A5','A6','D7']},
     index=[1,2,3,4])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df3= pd.DataFrame({'A':['A0','A1','A2','A3','A4','A5','A6','A7'],'B':['A0','A1','A2','A3','A4','A5','A6','A7'],'C':['A0','A1','A2','A3','A4','A5','A6','A7'],'D':['A0','A1','A2','A3','A4','A5','A6','D7']},
#       2      index=[1,2,3,4])
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:636, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     630     mgr = self._init_mgr(
#     631         data, axes={"index": index, "columns": columns}, dtype=dtype, copy=copy
#     632     )
#     634 elif isinstance(data, dict):
#     635     # GH#38939 de facto copy defaults to False only in non-dict cases
# --> 636     mgr = dict_to_mgr(data, index, columns, dtype=dtype, copy=copy, typ=manager)
#     637 elif isinstance(data, ma.MaskedArray):
# ...

# %%
from datetime import datetime
from datetime import timedelta

pd.date_range(start='13/6/2022',end='13/7/2021',freq = 'D')

start_dates = datetime.today()
dates_start = pd.date_range(start = start_dates, periods = 10,freq='T')
T= minutes
dates_start





import random
randomList=[]
for i in range (10):
    randomList.append(random.randint(0,1))

    df4 = pd.DataFrame()
    df4['start_date']=dates_start
    df4['end_date']= dates_end
    df4['Target']= randomList
    df4.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 8>()
#       6 start_dates = datetime.today()
#       7 dates_start = pd.date_range(start = start_dates, periods = 10,freq='T')
# ----> 8 T= minutes
#       9 dates_start
#      15 import random
#
# NameError: name 'minutes' is not defined
