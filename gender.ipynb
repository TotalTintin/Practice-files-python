# %%
import pandas as pd
import numpy as np

df = pd.read_excel("C:\\Users\\tinti\\Documents\\Statistical table1.xlsx")
df.head(10)
# Out:
#    HDI rank                 Country Gender Development Index Unnamed: 3  \
# 0       NaN                     NaN                    Value      Group
# 1       NaN                     NaN                     2019       2019
# 2       1.0                  Norway                 0.989939          1
# 3       2.0                 Ireland                 0.981024          1
# 4       2.0             Switzerland                 0.967513          2
# 5       4.0  Hong Kong, China (SAR)                 0.972323          2
# 6       4.0                 Iceland                 0.968674          2
# 7       6.0                 Germany                  0.97188          2
# 8       7.0                  Sweden                 0.982644          1
# 9       8.0               Australia                 0.976204          1
#
#   Human Development Index Unnamed: 5 Life expectancy at birth Unnamed: 7  \
# 0                  Female       Male                   Female       Male
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 197 entries, 0 to 196
# Data columns (total 14 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   HDI rank                                                  189 non-null    float64
#  1   Country                                                   195 non-null    object
#  2   Gender Development Index                                  197 non-null    object
#  3   Unnamed: 3                                                197 non-null    object
#  4   Human Development Index                                   197 non-null    object
#  5   Unnamed: 5                                                197 non-null    object
#  6   Life expectancy at birth                                  197 non-null    object
#  7   Unnamed: 7                                                197 non-null    object
# ...

# %%
df.set_index('HDI rank', inplace= True)
df.head(10)
# Out:
#                          Country Gender Development Index Unnamed: 3  \
# HDI rank
# NaN                          NaN                    Value      Group
# NaN                          NaN                     2019       2019
# 1.0                       Norway                 0.989939          1
# 2.0                      Ireland                 0.981024          1
# 2.0                  Switzerland                 0.967513          2
# 4.0       Hong Kong, China (SAR)                 0.972323          2
# 4.0                      Iceland                 0.968674          2
# 6.0                      Germany                  0.97188          2
# 7.0                       Sweden                 0.982644          1
# 8.0                    Australia                 0.976204          1
#
#          Human Development Index Unnamed: 5 Life expectancy at birth  \
# HDI rank
# NaN                       Female       Male                   Female
# ...

# %%
df.drop(df.iloc[:, 4:7,12:13], inplace=True, axis=1)
df.head(10)
# Out:
# ---------------------------------------------------------------------------
# IndexingError                             Traceback (most recent call last)
# Input In [42], in <cell line: 1>()
# ----> 1 df.drop(df.iloc[:, 4:7,12:13], inplace=True, axis=1)
#       2 df.head(10)
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:961, in _LocationIndexer.__getitem__(self, key)
#     959     if self._is_scalar_access(key):
#     960         return self.obj._get_value(*key, takeable=self._takeable)
# --> 961     return self._getitem_tuple(key)
#     962 else:
#     963     # we by definition only have the 0th axis
#     964     axis = self.axis or 0
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexing.py:1458, in _iLocIndexer._getitem_tuple(self, tup)
#    1456 def _getitem_tuple(self, tup: tuple):
# -> 1458     tup = self._validate_tuple_indexer(tup)
#    1459     with suppress(IndexingError):
#    1460         return self._getitem_lowerdim(tup)
#
# ...
